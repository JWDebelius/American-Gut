# %%
import numpy as np
import skbio
import pandas as pd
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
% matplotlib inline

import americangut.ag_dictionary as agdic
import americangut.diversity_analysis as agdiv
import americangut.notebook_environment as agenv
from americangut.ag_data import AgData
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# Let's load the full dataset, and explore it.

# %%
bodysite = 'fecal'
sequence_trim = '100nt'
rarefaction_depth = '10k'

use_subset = False
use_one_sample = True

# %%
fecal_data = AgData(bodysite=bodysite, 
                    trim=sequence_trim, 
                    depth=rarefaction_depth, 
                    sub_participants=use_subset, 
                    one_sample=use_one_sample)

# %%
fecal_data.drop_alpha_outliers()
fecal_data.drop_bmi_outliers()
fecal_data.clean_age()

# %%
ibd = {u'10317.000012951', u'10317.000017746', u'10317.000001620',
       u'10317.000001748', u'10317.000009382', u'10317.000001544',
       u'10317.000005953', u'10317.000009004', u'10317.000013010',
       u'10317.000014579', u'10317.000001827', u'10317.000013023',
       u'10317.000009157', u'10317.000001362', u'10317.000001135',
       u'10317.000004855', u'10317.000005878', u'10317.000007719',
       u'10317.000009126', u'10317.000007068', u'10317.000010134',
       u'10317.000010112', u'10317.000003300', u'10317.000002830',
       u'10317.000014236', u'10317.000012936', u'10317.000013575',
       u'10317.000001047', u'10317.000005360', u'10317.000001333',
       u'10317.000015581', u'10317.000003189', u'10317.000001128',
       u'10317.000015907', u'10317.000017338', u'10317.000013062',
       u'10317.000013595', u'10317.000009533', u'10317.000010546',
       u'10317.000001685', u'10317.000004163', u'10317.000001751',
       u'10317.000013551', u'10317.000005889', u'10317.000002036',
       u'10317.000002783', u'10317.000004157', u'10317.000001364',
       u'10317.000001622', u'10317.000004783', u'10317.000008999',
       u'10317.000009149', u'10317.000001895', u'10317.000011375',
       u'10317.000014880', u'10317.000001291', u'10317.000010876',
       u'10317.000014607', u'10317.000014987', u'10317.000002271',
       u'10317.000003898', u'10317.000009144', u'10317.000002482',
       u'10317.000014608', u'10317.000013134', u'10317.000001647',
       u'10317.000011959', u'10317.000009626', u'10317.000004025',
       u'10317.000014291', u'10317.000001351', u'10317.000002859',
       u'10317.000014118', u'10317.000004612', u'10317.000018383',
       u'10317.000001575', u'10317.000004161', u'10317.000015873',
       u'10317.000005971', u'10317.000004192', u'10317.000001322',
       u'10317.000004162', u'10317.000002336', u'10317.000010147',
       u'10317.000006673', u'10317.000004752', u'10317.000005851',
       u'10317.000009236', u'10317.000001363', u'10317.000014458',
       u'10317.000011093', u'10317.000009164', u'10317.000005810',
       u'10317.000003047', u'10317.000015849', u'10317.000004790',
       }
actual = set(ibd).intersection(fecal_data.map_.index)
# len(actual)
fecal_data.map_.loc[actual, 'IBD_DIAGONOSIS'] = 'Yes'

# %%
questions = ['IBD', 'SEX', 'ANTIBIOTIC_HISTORY', 'COUNTRY', 'RACE', 'BOWEL_MOVEMENT_QUALITY',
             'BOWEL_MOVEMENT_FREQUENCY', 'AGE_CORRECTED']

# %%
questions = ['AGE_CORRECTED', 'ALCOHOL_FREQUENCY', 
             'ANTIBIOTIC_HISTORY', 'BMI_CAT',
             'BOWEL_MOVEMENT_FREQUENCY', 'BOWEL_MOVEMENT_QUALITY', 'CAT',
             'CHICKENPOX', 'COLLECTION_MONTH', 'CONSUME_ANIMAL_PRODUCTS_ABX',
             'CONTRACEPTIVE', 'COUNTRY', 'CSECTION', 'DIABETES', 'DIET_TYPE',
             'DRINKING_WATER_SOURCE', 'EXERCISE_FREQUENCY', 'EXERCISE_LOCATION',
             'FED_AS_INFANT', 'FERMENTED_PLANT_FREQUENCY', 'FLOSSING_FREQUENCY',
             'FRUIT_FREQUENCY', 'GLUTEN', 'HOMECOOKED_MEALS_FREQUENCY', 'IBD',
             'LACTOSE', 'LAST_TRAVEL', 'LOWGRAIN_DIET_TYPE', 'LUNG_DISEASE',
             'MIGRAINE', 'MULTIVITAMIN', 'OLIVE_OIL',
             'ONE_LITER_OF_WATER_A_DAY_FREQUENCY', 'POOL_FREQUENCY',
             'PREPARED_MEALS_FREQUENCY', 'PROBIOTIC_FREQUENCY', 'RACE',
             'SEASONAL_ALLERGIES', 'SEX', 'SLEEP_DURATION', 'SMOKING_FREQUENCY',
             'SUGARY_SWEETS_FREQUENCY', 'TYPES_OF_PLANTS', 'VEGETABLE_FREQUENCY',
             'VITAMIN_B_SUPPLEMENT_FREQUENCY', 'VITAMIN_D_SUPPLEMENT_FREQUENCY',
             'WEIGHT_CHANGE']

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.formula.api as smf


def olf_build_model(response, predictors, data, dname=None, model_watch=None,
                    prev_id=None):
    """Builds up a series of Ordinary Least Squares Models

    """

    # Looks for the last model being referenced as the best
    id_, prev_id, prev_eq = _check_watch(model_watch, prev_id)

    if model_watch is None:
        model_watch = pd.DataFrame(data=np.zeros((0, 11)),
                                   columns=['data_set', 'equation', 'var', 'n',
                                            'k', 'aic', 'aicc', 'D_score',
                                            'pearson_r2', 'adj_r2', 'cond no'])
    # Builds up the model
    for var_ in predictors:
        # Builds up the list of equations to be added
        eqs = _equation_builder(var_, prev_eq, response)
        num_var = len(eqs)

        # Fits the equations
        fits = [smf.ols(eq, data=data).fit() for eq in eqs]

        # Summarizes the fit
        fit_check = _populate_fit_check(fits, var_, id_, dname)

        # Updates the fit check with the best previous model
        check_ids = fit_check.index.values
        if prev_id is None:
            prev_id = min(fit_check.index.values)
        else:
            fit_check.loc[prev_id] = model_watch.loc[prev_id]

        # Identifies the best model
        prev_id = identify_best_model(fit_check, prev_id)

        model_watch = pd.concat((model_watch, fit_check.loc[check_ids]))

        # Gets the best fit equation
        prev_eq = model_watch.loc[prev_id, 'equation']

        # Advances the counter
        id_ = id_ + num_var

    return model_watch, prev_eq, id_


def control_cat_order(df, category, old_order=None, new_order=None,
                      counts=None, drop=None):
    """..."""
    # Sets up default variables
    if old_order is None:
        old_order = sorted(df.groupby(category).groups.keys())
    if new_order is None:
        new_order = old_order
    if counts is None:
        counts = np.arange(0, len(new_order))
    if isinstance(drop, str):
        drop = [drop]
    elif drop is None:
        drop = []

    # Sets the dropped categories to nans
    for cat in drop:
        if cat in old_order:
            raise ValueError('%s cannot be dropped and categorized' % cat)
        df.loc[df[category] == cat, category] = np.nan

    # Orders the new category
    for (old_, new_, count) in zip(*[old_order, new_order, counts]):
        df.loc[df[category] == old_, category] = '(%i)%s' % (count, old_)


def _check_watch(model_watch, prev_id):
    """..."""
    if model_watch is None:
        model_watch = pd.DataFrame(data=np.zeros((0, 11)),
                                   columns=['data_set', 'equation', 'var', 'n',
                                            'k', 'aic', 'aicc', 'D_score',
                                            'pearson_r2', 'adj_r2', 'cond no'])
        id_ = 1
        prev_id = None
        prev_eq = None
    else:
        id_ = max(model_watch.keys()) + 1
        if prev_id is None:
            models = pd.DataFrame(model_watch).transpose()
            ranked = models.sort(['aicc'], inplace=False).index
            prev_id = ranked[0]
        prev_eq = model_watch[prev_id]['equation']
    return model_watch, id_, prev_id, prev_eq


def _equation_builder(vars_, last_eq=None, response=None):
    """Builds a set of equations trying multiple predictor options"""
    # Checks enough variables are defined
    if last_eq is None and response is None:
        raise ValueError('A response or last equation must be specified.')

    # Checks the class of vars
    if isinstance(vars_, str):
        vars_ = [vars_]

    # Builds the equation
    if last_eq is None:
        return ['%s ~ %s' % (response, pred) for pred in vars_]
    else:
        eqs = []
        for pred in vars_:
            if '&' in pred:
                eqs.append(last_eq.replace(' + %s' % pred[1:], ''))
            else:
                eqs.append('%s + %s' % (last_eq, pred))

    return eqs


def _populate_fit_check(fits, var_, id_=1, dname=None):
    """Updates the fit_check information"""
    fit_check = []
    if isinstance(var_, str):
        var_ = [var_]

    for idy, fit_ in enumerate(fits):
        n = fit_.nobs
        k = fit_.df_model
        aicc = fit_.aic + (2 * k * (k + 1) / (n - k - 1))
        d_score = scipy.stats.kstest(fit_.resid.values, 'norm')[0]

        fit_check.append(pd.Series({'data_set': dname,
                                    'equation':  fit_.model.formula,
                                    'var': var_[idy],
                                    'n': n,
                                    'k': k,
                                    'aic': fit_.aic,
                                    'aicc': aicc,
                                    'D_score': d_score,
                                    'pearson_r2': fit_.rsquared,
                                    'adj_r2': fit_.rsquared_adj,
                                    'cond no': fit_.condition_number},
                                   name=id_ + idy))
    return pd.DataFrame(fit_check)


def _identify_best_model(fit_check, prev_id):
    """..."""
    fit_check['ref'] = prev_id
    prev_r2 = fit_check.loc[prev_id, 'adj_r2']
    prev_aicc = fit_check.loc[prev_id, 'aicc']
    fit_check['score'] = -10000*(((fit_check.adj_r2 - prev_r2) *
                                 (fit_check.aicc - prev_aicc)) /
                                 fit_check['cond no'])
    prev_id = fit_check.loc[fit_check.score == fit_check.score.max()].index[0]
    return prev_id

# %%
fecal_data.map_.groupby('CAT').count().max(1)
# Out:
# CAT
# false    2672
# true     1079
# dtype: int64

# %%
fecal_data.map_.AGE_CORRECTED.min()
# Out:
# 1.0

# %%
for name in questions[:-1]:
    question = agdic.ag_dictionary(name)
    if name == 'COUNTRY':
        question.order = ['USA', 'Australia', 'Canada', 'United Kingdom']
    elif name == 'IBD':
        question.order = ['No', 'Yes']
    fecal_data.clean_group(question)
    if name == 'AGE_CORRECTED':
        continue
    question.label_order(fecal_data.map_)
map_ = fecal_data.map_

# %%
actual = set(ibd).intersection(map_.index)
map_.loc[actual, 'IBD'] = '(0) Yes'

# %%
map_.groupby('IBD').count().max(1)
# Out:
# IBD
# (0) No     3480
# (0) Yes      87
# dtype: int64

# %%
map_.AGE_CORRECTED.min()
# Out:
# 1.0

# %%
map_['lnAGE'] = map_['AGE_CORRECTED'].apply(lambda x: np.log(x))

# %%
watch_cols = questions
watch_cols.append('lnAGE')
watch_cols.append('PD_whole_tree_10k')

# %%
map_[watch_cols].dropna()
# Out:
#                  AGE_CORRECTED      ALCOHOL_FREQUENCY    ANTIBIOTIC_HISTORY  \
# #SampleID
# 10317.000010102             33     (3) 3-5 times/week  (3) More than a year
# 10317.000007728             73     (3) 3-5 times/week  (3) More than a year
# 10317.000014890             56     (3) 3-5 times/week  (3) More than a year
# 10317.000018362             51              (0) Never  (3) More than a year
# 10317.000001892             50  (1) A few times/month  (3) More than a year
# 10317.000013378             74     (2) 1-2 times/week  (3) More than a year
# 10317.000009148             45     (2) 1-2 times/week  (3) More than a year
# 10317.000015594             55     (3) 3-5 times/week  (3) More than a year
# 10317.000011191             32     (3) 3-5 times/week  (3) More than a year
# 10317.000003001             45     (2) 1-2 times/week          (1) 6 months
# 10317.000012007             53  (1) A few times/month  (3) More than a year
# 10317.000014930             73              (4) Daily             (0) Month
# 10317.000011080             56              (4) Daily  (3) More than a year
# 10317.000011022             83              (0) Never  (3) More than a year
# 10317.000010715             56  (1) A few times/month  (3) More than a year
# 10317.000012923             48              (4) Daily  (3) More than a year
# 10317.000015616             56              (4) Daily  (3) More than a year
# 10317.000003531             43     (3) 3-5 times/week  (3) More than a year
# 10317.000016316             36              (0) Never  (3) More than a year
# 10317.000001651             62  (1) A few times/month  (3) More than a year
# 10317.000001252             30     (2) 1-2 times/week  (3) More than a year
# 10317.000010908             45              (0) Never  (3) More than a year
# 10317.000012044             47  (1) A few times/month  (3) More than a year
# 10317.000016501             27  (1) A few times/month  (3) More than a year
# 10317.000013027             48     (3) 3-5 times/week  (3) More than a year
# 10317.000014093             47     (2) 1-2 times/week  (3) More than a year
# 10317.000001955             66     (3) 3-5 times/week  (3) More than a year
# 10317.000010939             68  (1) A few times/month              (2) Year
# 10317.000017647             30     (3) 3-5 times/week  (3) More than a year
# 10317.000006911             68  (1) A few times/month  (3) More than a year
# ...                        ...                    ...                   ...
# 10317.000009607             56     (3) 3-5 times/week  (3) More than a year
# 10317.000001820             33  (1) A few times/month  (3) More than a year
# 10317.000014682             46     (2) 1-2 times/week  (3) More than a year
# 10317.000002632             53              (4) Daily             (0) Month
# 10317.000002587             37  (1) A few times/month  (3) More than a year
# 10317.000011243             55              (0) Never  (3) More than a year
# 10317.000012310             47     (2) 1-2 times/week  (3) More than a year
# 10317.000014009             50     (3) 3-5 times/week  (3) More than a year
# 10317.000010110             43  (1) A few times/month  (3) More than a year
# 10317.000010905             56              (4) Daily  (3) More than a year
# 10317.000014169             62     (2) 1-2 times/week              (2) Year
# 10317.000003430             37  (1) A few times/month  (3) More than a year
# 10317.000009583             67     (3) 3-5 times/week  (3) More than a year
# 10317.000012285             31     (2) 1-2 times/week  (3) More than a year
# 10317.000002587             (0) Normal  (0) yes    (1) Yes         (6) July
# 10317.000011243             (0) Normal   (1) no    (1) Yes     (1) February
# 10317.000012310             (0) Normal   (1) no    (1) Yes     (1) February
# 10317.000014009           (2) Diarrhea   (1) no    (1) Yes    (8) September
# 10317.000010110        (1) Constipated   (1) no    (1) Yes     (1) February
# 10317.000010905             (0) Normal  (0) yes    (1) Yes     (1) February
# 10317.000014169             (0) Normal   (1) no    (1) Yes        (2) March
# 10317.000003430             (0) Normal   (1) no    (1) Yes        (3) April
# 10317.000009583             (0) Normal   (1) no    (1) Yes    (8) September
# 10317.000012285           (2) Diarrhea  (0) yes    (1) Yes    (11) December
# 10317.000001878             (0) Normal   (1) no    (1) Yes        (3) April
# 10317.000008964             (0) Normal   (1) no    (1) Yes    (10) November
# 10317.000013971        (1) Constipated   (1) no     (0) No        (2) March
# 10317.000005732             (0) Normal   (1) no    (1) Yes        (2) March
# 10317.000002520             (0) Normal   (1) no    (1) Yes        (3) April
# 10317.000014869             (0) Normal   (1) no    (1) Yes        (3) April
# 10317.000011337             (0) Normal  (0) yes    (1) Yes    (11) December
# 10317.000013372           (2) Diarrhea   (1) no    (1) Yes      (0) January
# 10317.000015826           (2) Diarrhea   (1) no    (1) Yes        (3) April
# 10317.000017161             (0) Normal   (1) no    (1) Yes         (6) July
# 10317.000003098             (0) Normal  (0) yes    (1) Yes        (2) March
# 10317.000013823             (0) Normal  (0) yes    (1) Yes     (1) February
# 10317.000014187             (0) Normal   (1) no    (1) Yes        (3) April
# 10317.000002631             (0) Normal  (0) yes     (0) No        (3) April
# 10317.000011416           (2) Diarrhea   (1) no    (1) Yes      (0) January
# 10317.000016325             (0) Normal   (1) no    (1) Yes          (4) May
#
#                 CONSUME_ANIMAL_PRODUCTS_ABX        ...         \
# #SampleID                                          ...
# 10317.000010102                     (1) Yes        ...
# 10317.000007728                      (0) No        ...
# 10317.000014890                      (0) No        ...
# 10317.000018362                      (0) No        ...
# 10317.000001892                      (0) No        ...
# 10317.000013378                     (1) Yes        ...
# 10317.000009148                     (1) Yes        ...
# 10317.000015594                      (0) No        ...
# 10317.000011191                      (0) No        ...
# 10317.000003001                     (1) Yes        ...
# 10317.000012007                     (1) Yes        ...
# 10317.000014930                      (0) No        ...
# 10317.000011080                     (1) Yes        ...
# 10317.000011022                     (1) Yes        ...
# 10317.000010715                      (0) No        ...
# 10317.000012923                     (1) Yes        ...
# 10317.000015616                     (1) Yes        ...
# 10317.000003531                      (0) No        ...
# 10317.000016316                      (0) No        ...
# 10317.000001651                      (0) No        ...
# 10317.000001252                      (0) No        ...
# 10317.000010908                      (0) No        ...
# 10317.000012044                      (0) No        ...
# 10317.000016501                     (1) Yes        ...
# 10317.000013027                      (0) No        ...
# 10317.000014093                     (1) Yes        ...
# 10317.000001955                      (0) No        ...
# 10317.000010939                      (0) No        ...
# 10317.000017647                      (0) No        ...
# 10317.000006911                      (0) No        ...
# ...                                     ...        ...
# 10317.000009607                      (0) No        ...
# 10317.000001820                      (0) No        ...
# 10317.000012310         28.466141         28.466141
# 10317.000014009         26.162613         26.162613
# 10317.000010110         44.924389         44.924389
# 10317.000010905         38.840924         38.840924
# 10317.000014169         34.338442         34.338442
# 10317.000003430         25.573525         25.573525
# 10317.000009583         26.437005         26.437005
# 10317.000012285         33.975704         33.975704
# 10317.000001878         26.725545         26.725545
# 10317.000008964         34.169629         34.169629
# 10317.000013971         31.797127         31.797127
# 10317.000005732         36.391645         36.391645
# 10317.000002520         29.205657         29.205657
# 10317.000014869         33.837907         33.837907
# 10317.000011337         41.190748         41.190748
# 10317.000013372         23.113712         23.113712
# 10317.000015826         27.196295         27.196295
# 10317.000017161         26.918458         26.918458
# 10317.000003098         46.063391         46.063391
# 10317.000013823         35.293398         35.293398
# 10317.000014187         35.337542         35.337542
# 10317.000002631         30.834526         30.834526
# 10317.000011416         22.888672         22.888672
# 10317.000016325         27.818513         27.818513
#
# [69 rows x 49 columns]

# %%
eq = None
model_watch = None
id_=0
prev_id = None
for var in watch_cols[:-1]:
    eqs = _equation_builder(var,
                           response='PD_whole_tree_10k',
                           last_eq=eq
                           )
    fits = [smf.ols(eq, data=map_[watch_cols]).fit() for eq in eqs]
    fit_check = _populate_fit_check(fits, var, id_, '')
    
    check_ids = fit_check.index.values
    if prev_id is None:
        prev_id = min(fit_check.index.values)
#     else:
#         fit_check.loc[prev_id] = model_watch.loc[prev_id]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-d7c6ea7638bf> in <module>()
#       9                            )
#      10     fits = [smf.ols(eq, data=map_[watch_cols]).fit() for eq in eqs]
# ---> 11     fit_check = _populate_fit_check(fits, var, id_, '')
#      12
#      13     check_ids = fit_check.index.values
#
# <ipython-input-12-a99abdf26caf> in _populate_fit_check(fits, var_, id_, dname)
#     129         k = fit_.df_model
#     130         aicc = fit_.aic + (2 * k * (k + 1) / (n - k - 1))
# --> 131         d_score = scipy.stats.kstest(fit_.resid.values, 'norm')[0]
#     132
#     133         fit_check.append(pd.Series({'data_set': dname,
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/scipy/stats/stats.pyc in kstest(rvs, cdf, args, N, alternative, mode)
#    4131
#    4132     if alternative in ['two-sided', 'greater']:
# -> 4133         Dplus = (np.arange(1.0, N + 1)/N - cdfvals).max()
#    4134         if alternative == 'greater':
#    4135             return KstestResult(Dplus, distributions.ksone.sf(Dplus, N))
#
# ValueError: operands could not be broadcast together with shapes (3746,) (3746,2)

# %%
age_ = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=map_[watch_cols]).fit()

# %%
print age_.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-7a23768c2855> in <module>()
# ----> 1 print age_.summary()
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in summary(self, yname, xname, title, alpha)
#    1948             top_left.append(('Covariance Type:', [self.cov_type]))
#    1949
# -> 1950         top_right = [('R-squared:', ["%#8.3f" % self.rsquared]),
#    1951                      ('Adj. R-squared:', ["%#8.3f" % self.rsquared_adj]),
#    1952                      ('F-statistic:', ["%#8.4g" % self.fvalue] ),
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      92         if _cachedval is None:
#      93             # Call the "fget" function
# ---> 94             _cachedval = self.fget(obj)
#      95             # Set the attribute in obj
#      96 #            print("Setting %s in cache to %s" % (name, _cachedval))
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in rsquared(self)
#    1179     def rsquared(self):
#    1180         if self.k_constant:
# -> 1181             return 1 - self.ssr/self.centered_tss
#    1182         else:
#    1183             return 1 - self.ssr/self.uncentered_tss
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      92         if _cachedval is None:
#      93             # Call the "fget" function
# ---> 94             _cachedval = self.fget(obj)
#      95             # Set the attribute in obj
#      96 #            print("Setting %s in cache to %s" % (name, _cachedval))
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in ssr(self)
#    1151     def ssr(self):
#    1152         wresid = self.wresid
# -> 1153         return np.dot(wresid, wresid)
#    1154
#    1155     @cache_readonly
#
# ValueError: shapes (3746,3) and (3746,3) not aligned: 3 (dim 1) != 3746 (dim 0)

# %%
print lage.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-3a72a47f3ff9> in <module>()
# ----> 1 print lage.summary()
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in summary(self, yname, xname, title, alpha)
#    1948             top_left.append(('Covariance Type:', [self.cov_type]))
#    1949
# -> 1950         top_right = [('R-squared:', ["%#8.3f" % self.rsquared]),
#    1951                      ('Adj. R-squared:', ["%#8.3f" % self.rsquared_adj]),
#    1952                      ('F-statistic:', ["%#8.4g" % self.fvalue] ),
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      92         if _cachedval is None:
#      93             # Call the "fget" function
# ---> 94             _cachedval = self.fget(obj)
#      95             # Set the attribute in obj
#      96 #            print("Setting %s in cache to %s" % (name, _cachedval))
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in rsquared(self)
#    1179     def rsquared(self):
#    1180         if self.k_constant:
# -> 1181             return 1 - self.ssr/self.centered_tss
#    1182         else:
#    1183             return 1 - self.ssr/self.uncentered_tss
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/tools/decorators.pyc in __get__(self, obj, type)
#      92         if _cachedval is None:
#      93             # Call the "fget" function
# ---> 94             _cachedval = self.fget(obj)
#      95             # Set the attribute in obj
#      96 #            print("Setting %s in cache to %s" % (name, _cachedval))
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in ssr(self)
#    1151     def ssr(self):
#    1152         wresid = self.wresid
# -> 1153         return np.dot(wresid, wresid)
#    1154
#    1155     @cache_readonly
#
# ValueError: shapes (3746,3) and (3746,3) not aligned: 3 (dim 1) != 3746 (dim 0)

# %%
map_.groupby('SEX').count().max(1)

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY + TYPES_OF_PLANTS', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + '
               'ANTIBIOTIC_HISTORY + TYPES_OF_PLANTS + BMI_CAT', 
               data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + '
               'ANTIBIOTIC_HISTORY + TYPES_OF_PLANTS + BMI_CAT + EXERCISE_FREQUENCY', 
               data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + ANTIBIOTIC_HISTORY + BOWEL_MOVEMENT_QUALITY', data=map_[watch_cols]).fit()
print age2.summary()

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + ANTIBIOTIC_HISTORY + CHICKENPOX', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-54b5ab9ead4e> in <module>()
# ----> 1 age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + ANTIBIOTIC_HISTORY + CHICKENPOX', data=map_[watch_cols]).fit()
#       2 print age2.summary()
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#     145         (endog, exog), missing_idx = handle_formula_data(data, None, formula,
#     146                                                          depth=eval_env,
# --> 147                                                          missing=missing)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     295     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     296     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
#     299         raise PatsyError("model is missing required outcome variables")
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     150         return iter([data])
#     151     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 152                                       NA_action)
#     153     if design_infos is not None:
#     154         return build_design_matrices(design_infos, data,
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/highlevel.pyc in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      55                                       data_iter_maker,
#      56                                       eval_env,
# ---> 57                                       NA_action)
#      58     else:
#      59         return None
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/build.pyc in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     694                                                    factor_states,
#     695                                                    data_iter_maker,
# --> 696                                                    NA_action)
#     697     # Now we need the factor infos, which encapsulate the knowledge of
#     698     # how to turn any given factor into a chunk of data:
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/build.pyc in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     441     for data in data_iter_maker():
#     442         for factor in list(examine_needed):
# --> 443             value = factor.eval(factor_states[factor], data)
#     444             if factor in cat_sniffers or guess_categorical(value):
#     445                 if factor not in cat_sniffers:
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/eval.pyc in eval(self, memorize_state, data)
#     564         return self._eval(memorize_state["eval_code"],
#     565                           memorize_state,
# --> 566                           data)
#     567
#     568     __getstate__ = no_pickling
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/eval.pyc in _eval(self, code, memorize_state, data)
#     549                                  memorize_state["eval_env"].eval,
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#     553     def memorize_chunk(self, state, which_pass, data):
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/compat.pyc in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     115 def call_and_wrap_exc(msg, origin, f, *args, **kwargs):
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#     119         if sys.version_info[0] >= 3:
#
# /Users/jdebelius/miniconda2/envs/americangut/lib/python2.7/site-packages/patsy/eval.pyc in eval(self, expr, source_name, inner_namespace)
#     164         code = compile(expr, source_name, "eval", self.flags, False)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#     168     @classmethod
#
# <string> in <module>()
#
# NameError: name 'lnAGE' is not defined

# %%
questions
# Out:
# ['IBD',
#  'SEX',
#  'ANTIBIOTIC_HISTORY',
#  'COUNTRY',
#  'RACE',
#  'BOWEL_MOVEMENT_QUALITY',
#  'BOWEL_MOVEMENT_FREQUENCY',
#  'AGE_CORRECTED',
#  'VIOSCREEN_MANNITOL',
#  'VIOSCREEN_SFA100',
#  'VIOSCREEN_SFA170',
#  'VIOSCREEN_VEGETABLE_SERVINGS',
#  'VIOSCREEN_SORBITOL',
#  'VIOSCREEN_SFA80',
#  'VIOSCREEN_BETACAR',
#  'VIOSCREEN_LOW_FAT_DAIRY_SERVING',
#  'VIOSCREEN_NIACINEQ',
#  'VIOSCREEN_GAMMTOCO',
#  'VIOSCREEN_LYSINE',
#  'VIOSCREEN_ISOMALT',
#  'VIOSCREEN_SUCROSE',
#  'VIOSCREEN_CLAC9T11',
#  'VIOSCREEN_FIBER',
#  'VIOSCREEN_LACTITOL',
#  'VIOSCREEN_HEI_NON_JUICE_FRT',
#  'VIOSCREEN_OXALICM',
#  'VIOSCREEN_ALPHACAR',
#  'VIOSCREEN_LYCOPENE',
#  'VIOSCREEN_VEG5_DAY',
#  'VIOSCREEN_HEI_MILK',
#  'VIOSCREEN_CLAT10C12',
#  'VIOSCREEN_HEI_MEAT_BEANS',
#  'VIOSCREEN_HEI_SOL_FAT_ALC_ADD_SUG',
#  'VIOSCREEN_COPPER',
#  'VIOSCREEN_HEI2010_REFINED_GRAINS',
#  'VIOSCREEN_LUTZEAX',
#  'VIOSCREEN_SALAD_VEGETABLE_SERVINGS',
#  'VIOSCREEN_SFA200',
#  'VIOSCREEN_HEI2010_DAIRY',
#  'VIOSCREEN_FIBH2O',
#  'VIOSCREEN_GLAC',
#  'VIOSCREEN_SFA140',
#  'VIOSCREEN_TAGATOSE',
#  'VIOSCREEN_D_YOGURT',
#  'VIOSCREEN_VISIT',
#  'VIOSCREEN_HEI2010_WHOLE_GRAINS',
#  'VIOSCREEN_MULTI_CALCIUM_AVG',
#  'VIOSCREEN_F_NJ_OTHER',
#  'VIOSCREEN_D_MILK',
#  'VIOSCREEN_M_ORGAN',
#  'VIOSCREEN_M_POULT',
#  'VIOSCREEN_M_MPF',
#  'VIOSCREEN_WHOLE_GRAIN_SERVINGS',
#  'VIOSCREEN_HEI2010_PROTIEN_FOODS',
#  'VIOSCREEN_NCCGLGR',
#  'VIOSCREEN_OXALIC',
#  'VIOSCREEN_HEI_FRUIT',
#  'VIOSCREEN_MFA161',
#  'VIOSCREEN_SATOCO',
#  'VIOSCREEN_RIBOFLA',
#  'VIOSCREEN_STARCH',
#  'VIOSCREEN_MFA221',
#  'VIOSCREEN_V_TOTAL',
#  'VIOSCREEN_V_ORANGE',
#  'VIOSCREEN_M_FRANK',
#  'VIOSCREEN_DELTTOCO',
#  'VIOSCREEN_FRUIT_SERVINGS',
#  'VIOSCREEN_BETATOCO',
#  'VIOSCREEN_FRIED_FOOD_SERVINGS',
#  'VIOSCREEN_FISH_SERVINGS',
#  'VIOSCREEN_FRTSUMM',
#  'VIOSCREEN_GRAMS',
#  'VIOSCREEN_VALINE',
#  'VIOSCREEN_HEI_SODIUM',
#  'VIOSCREEN_HISTIDIN',
#  'VIOSCREEN_BETAINE',
#  'VIOSCREEN_ALCOHOL_SERVINGS',
#  'VIOSCREEN_SFATOT',
#  'VIOSCREEN_POTASS',
#  'VIOSCREEN_PHYTIC',
#  'VIOSCREEN_PECTINS',
#  'VIOSCREEN_SFA180',
#  'VIOSCREEN_FOL_SYN',
#  'VIOSCREEN_F_NJ_TOTAL',
#  'VIOSCREEN_A_CAL',
#  'VIOSCREEN_V_TOMATO',
#  'VIOSCREEN_LEUCINE',
#  'VIOSCREEN_CALORIES',
#  'VIOSCREEN_A_BEV',
#  'VIOSCREEN_HEI2010_EMPTY_CALORIES',
#  'VIOSCREEN_LEGUMES',
#  'VIOSCREEN_BETACRYP',
#  'VIOSCREEN_HEI2010_SODIUM',
#  'VIOSCREEN_TRYPTOPH',
#  'VIOSCREEN_TOTALTFA',
#  'VIOSCREEN_ALCOHOL',
#  'VIOSCREEN_SACCHAR',
#  'VIOSCREEN_ERYTHR',
#  'VIOSCREEN_D_TOTAL',
#  'VIOSCREEN_F_TOTAL',
#  'VIOSCREEN_NON_FRIED_FISH_SERVINGS',
#  'VIOSCREEN_ADD_SUG',
#  'VIOSCREEN_PFA225',
#  'VIOSCREEN_PFA226',
#  'VIOSCREEN_HEI_SCORE',
#  'VIOSCREEN_FAT',
#  'VIOSCREEN_PROLINE',
#  'VIOSCREEN_M_MEAT',
#  'VIOSCREEN_CALCIUM_AVG',
#  'VIOSCREEN_G_WHL',
#  'VIOSCREEN_PROTANIM',
#  'VIOSCREEN_MALTITOL',
#  'VIOSCREEN_CALCIUM_SERVINGS',
#  'VIOSCREEN_FOL_NAT',
#  'VIOSCREEN_MAGNES',
#  'VIOSCREEN_VITA_RE',
#  'VIOSCREEN_VEGSUMM',
#  'VIOSCREEN_SFA60',
#  'VIOSCREEN_HEI2010_WHOLE_FRUIT',
#  'VIOSCREEN_HEI_SAT_FAT',
#  'VIOSCREEN_TOTFOLAT',
#  'VIOSCREEN_ARGININE',
#  'VIOSCREEN_HEI2010_FATTY_ACIDS',
#  'VIOSCREEN_PHENYLAL',
#  'VIOSCREEN_ALPHTOCE',
#  'VIOSCREEN_PROTEIN',
#  'VIOSCREEN_ALPHTOCO',
#  'VIOSCREEN_GLTC',
#  'VIOSCREEN_MULTI_CALCIUM_DOSE',
#  'VIOSCREEN_VITA_IU',
#  'VIOSCREEN_NIACIN',
#  'VIOSCREEN_SELENIUM',
#  'VIOSCREEN_TOTCLA',
#  'VIOSCREEN_PFA184',
#  'VIOSCREEN_PFA183',
#  'VIOSCREEN_PFA182',
#  'VIOSCREEN_D_TOT_SOYM',
#  'VIOSCREEN_DISCFAT_OIL',
#  'VIOSCREEN_GALACTOS',
#  'VIOSCREEN_JUICE_SERVINGS',
#  'VIOSCREEN_FRT5_DAY',
#  'VIOSCREEN_PINITOL',
#  'VIOSCREEN_GENISTN',
#  'VIOSCREEN_SFA120',
#  'VIOSCREEN_HEI_GRAINS',
#  'VIOSCREEN_METHION',
#  'VIOSCREEN_HEI_VEG',
#  'VIOSCREEN_GLUCOSE',
#  'VIOSCREEN_CHOLINE',
#  'VIOSCREEN_ISOLEUC',
#  'VIOSCREEN_FOL_DEQV',
#  'VIOSCREEN_COUMEST',
#  'VIOSCREEN_TFA161T',
#  'VIOSCREEN_XYLITOL',
#  'VIOSCREEN_BIOCHANA',
#  'VIOSCREEN_F_NJ_CITMLB',
#  'VIOSCREEN_HEI2010_VEG',
#  'VIOSCREEN_M_NUTSD',
#  'VIOSCREEN_PFATOT',
#  'VIOSCREEN_FIBINSO',
#  'VIOSCREEN_V_OTHER',
#  'VIOSCREEN_WGRAIN',
#  'VIOSCREEN_TFA182T',
#  'VIOSCREEN_G_TOTAL',
#  'VIOSCREEN_M_FISH_LO',
#  'VIOSCREEN_VITD2',
#  'VIOSCREEN_RETINOL',
#  'VIOSCREEN_MFATOT',
#  'VIOSCREEN_CYSTINE',
#  'VIOSCREEN_V_POTATO',
#  'VIOSCREEN_PANTOTHE',
#  'VIOSCREEN_RECNO',
#  'VIOSCREEN_ASH',
#  'VIOSCREEN_PHOSPHOR',
#  'VIOSCREEN_CALCIUM_FROM_DAIRY_SERVINGS',
#  'VIOSCREEN_ASPARTIC',
#  'VIOSCREEN_V_STARCY',
#  'VIOSCREEN_SFA220',
#  'VIOSCREEN_F_CITMLB',
#  'VIOSCREEN_HEI_WHL_GRAINS',
#  'VIOSCREEN_THREONIN',
#  'VIOSCREEN_M_EGG',
#  'VIOSCREEN_HEI2010_FRUIT',
#  'VIOSCREEN_DISCFAT_SOL',
#  'VIOSCREEN_TYROSINE',
#  'VIOSCREEN_WATER',
#  'VIOSCREEN_MFA141',
#  'VIOSCREEN_HEI2010_SCORE',
#  'VIOSCREEN_VITD',
#  'VIOSCREEN_VITC',
#  'VIOSCREEN_VITK',
#  'VIOSCREEN_SFA160',
#  'VIOSCREEN_FRUCTOSE',
#  'VIOSCREEN_ADDSUGAR',
#  'VIOSCREEN_MFA201',
#  'VIOSCREEN_RGRAIN',
#  'VIOSCREEN_V_DRKGR',
#  'VIOSCREEN_CALCIUM_DOSE',
#  'VIOSCREEN_F_OTHER',
#  'VIOSCREEN_ADSUGTOT',
#  'VIOSCREEN_IRON',
#  'VIOSCREEN_ZINC',
#  'VIOSCREEN_AVCARB',
#  'VIOSCREEN_OMEGA3',
#  'VIOSCREEN_TOTSUGAR',
#  'VIOSCREEN_SRVID',
#  'VIOSCREEN_LINE_GI',
#  'VIOSCREEN_TGRAIN',
#  'VIOSCREEN_SUCRLOSE',
#  'VIOSCREEN_M_SOY',
#  'VIOSCREEN_SUCPOLY',
#  'VIOSCREEN_ALANINE',
#  'VIOSCREEN_CARBO',
#  'VIOSCREEN_MFA181',
#  'VIOSCREEN_M_FISH_HI',
#  'VIOSCREEN_TFA181T',
#  'VIOSCREEN_VITD3',
#  'VIOSCREEN_ACESUPOT',
#  'VIOSCREEN_GLUTAMIC',
#  'VIOSCREEN_HEI2010_SEA_FOODS_PLANT_PROTIENS',
#  'VIOSCREEN_SODIUM',
#  'VIOSCREEN_THIAMIN',
#  'VIOSCREEN_ASPARTAM',
#  'VIOSCREEN_VITD_IU',
#  'VIOSCREEN_USER_ID',
#  'VIOSCREEN_HEI_DRK_G_ORG_VEG_LEG',
#  'VIOSCREEN_INOSITOL',
#  'VIOSCREEN_FRIED_FISH_SERVINGS',
#  'VIOSCREEN_VITB12',
#  'VIOSCREEN_SFA40',
#  'VIOSCREEN_TIME',
#  'VIOSCREEN_VITE_IU',
#  'VIOSCREEN_VITA_RAE',
#  'VIOSCREEN_MANGAN',
#  'VIOSCREEN_PROTVEG',
#  'VIOSCREEN_AGE',
#  'VIOSCREEN_GLYCITN',
#  'VIOSCREEN_GLYCINE',
#  'VIOSCREEN_LACTOSE',
#  'VIOSCREEN_VITB6',
#  'VIOSCREEN_D_CHEESE',
#  'VIOSCREEN_NCCGLBR',
#  'VIOSCREEN_HEI2010_GREENS_BEANS',
#  'VIOSCREEN_CAFFEINE',
#  'VIOSCREEN_DAIDZEIN',
#  'VIOSCREEN_NITROGEN',
#  'VIOSCREEN_SERINE',
#  'VIOSCREEN_PFA204',
#  'VIOSCREEN_PFA205',
#  'VIOSCREEN_G_NWHL',
#  'VIOSCREEN_MALTOSE',
#  'VIOSCREEN_HEI_OILS',
#  'VIOSCREEN_JOULES',
#  'VIOSCREEN_FORMONTN',
#  'VIOSCREEN_SWEET_SERVINGS',
#  'VIOSCREEN_CHOLEST',
#  'VIOSCREEN_METHHIS3',
#  'VIOSCREEN_NATOCO',
#  'PD_whole_tree_10k',
#  'lnAGE']

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=map_.loc[map_.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map = map_.loc[map_[['AGE_CORRECTED', 'VIOSCREEN_FIBER']].dropna().index]
sub_map['COUNTRY'] = sub_map.COUNTRY.apply(lambda x: x if x in {'USA', 'United Kingdom'} else np.nan)

# %%
f_ = lambda x: x if x in {'USA', 'United Kingdom'} else np.nan

# %%
abx = agdic.ag_dictionary('ANTIBIOTIC_HISTORY')
abx.remap_groups(sub_map)
abx.label_order(sub_map)

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map['lnAge'] = sub_map.AGE_CORRECTED.apply(lambda x: np.log(x))
sub_map.loc[sub_map.AGE_CORRECTED < 20, 'lnAge'] = np.nan

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge + COUNTRY', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge + COUNTRY + ANTIBIOTIC_HISTORY', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED + COUNTRY + VIOSCREEN_HEI_SCORE', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map.loc[sub_map.AGE_CORRECTED > 20].shape

# %%
plt.plot(map_['VIOSCREEN_FIBER'], map_['PD_whole_tree_10k'], 'o')

# %%
sorted(vios_cols)

# %%
vios_cols
