# %%
import numpy as np
import skbio
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.api as sms

import matplotlib.pyplot as plt
% matplotlib inline

import americangut.ag_dictionary as agdic
import americangut.diversity_analysis as agdiv
import americangut.notebook_environment as agenv
from americangut.ag_data import AgData

# %%
bodysite = 'fecal'
sequence_trim = '100nt'
rarefaction_depth = '10k'

use_subset = False
use_one_sample = True

# %%
fecal_data = AgData(bodysite=bodysite, 
                    trim=sequence_trim, 
                    depth=rarefaction_depth, 
                    sub_participants=use_subset, 
                    one_sample=use_one_sample)

# %%
fecal_data.drop_alpha_outliers()
fecal_data.drop_bmi_outliers()
fecal_data.clean_age()

# %%
vios_skip = {'VIOSCREEN_FINISHED',
             'VIOSCREEN_DATABASE',
             'VIOSCREEN_MULTIVITAMIN',
             'VIOSCREEN_QUESTIONNAIRE',
             'VIOSCREEN_GENDER',
             'VIOSCREEN_SCFV',
             'VIOSCREEN_PROTOCOL',
             'VIOSCREEN_CALCIUM_FREQ',
             'VIOSCREEN_CALCIUM',
             'VIOSCREEN_STARTED',
             'VIOSCREEN_NUTRIENT_RECOMMENDATION',
             'VIOSCREEN_PROCDATE',
             'VIOSCREEN_DOB',
             'VIOSCREEN_SCF',
             'VIOSCREEN_MULTIVITAMIN_FREQ'}
vios_cols = [x for x in fecal_data.map_.columns if 'VIOSCREEN' in x and not x in vios_skip]
for col in vios_cols:
    fecal_data.map_[col] = fecal_data.map_[col].astype(float)

# %%
vios_map = fecal_data.map_.loc[fecal_data.map_.VIOSCREEN_FINISHED.dropna().index, vios_cols]
vios_map.replace(np.nan, 0, inplace=True)

# %%
vios_cols[0]
# Out:
# 'VIOSCREEN_MANNITOL'

# %%
vios_otus = pd.DataFrame(np.vstack([fecal_data.otu_.data(id_, 'observation') 
                                    for id_ in fecal_data.otu_.ids('observation')]),
                         columns=fecal_data.otu_.ids('sample'), 
                         index=fecal_data.otu_.ids('observation')).transpose()

# %%
vios_map.shape
# Out:
# (326, 250)

# %%
vios_drop = (vios_otus.sum(0) > 0.1*vios_map.shape[0]) & (vios_otus.sum(0) < 0.9*vios_map.shape[0])

# %%
# Out:
# (3867, 23060)

# %%
vios_sub = (vios_otus.loc[vios_map.index, vios_drop.loc[vios_drop].index] > 0).astype(int)

# %%
vios_sub.columns[0]
# Out:
# u'1081058'

# %%
mannitol_fits = {}
for otu_id in vios_sub.columns:
    try:
        model = sms.Logit(vios_sub[otu_id], sms.add_constant(vios_map['VIOSCREEN_MANNITOL'])).fit()
        mannitol_fits[otu_id] = {'model': model,
                                 'p-value': model.llr_pvalue,
                                 'pseudo-r2': model.prsquared,
                                 'OR': 
                                 
                                 }
    except:
        mannitol_fits[otu_id] = 'no fit'
# Out:
# Optimization terminated successfully.
#          Current function value: 0.051710
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.103619
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.051971
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.037342
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.091147
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.079233
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.014932
#          Iterations 13
# Optimization terminated successfully.
#          Current function value: 0.034170
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.019054
#          Iterations 12
# Optimization terminated successfully.
#          Current function value: 0.228605
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.145337
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.115130
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.177156
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.126283
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.091567
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.137079
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.050600
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.016871
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.020103
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.108945
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.050946
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.123187
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.167110
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.014672
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.136600
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.036055
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.031938
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.020181
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.052794
#          Iterations 11
# Optimization terminated successfully.
#          Current function value: 0.037256
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.126323
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.091078
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.020805
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.049371
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.065983
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0
# 10317.000023015            9.439425          8.772083          29.942194
# 10317.000031468            3.554822          8.380685          27.403765
# 10317.000027213           22.053973          9.012301          24.907399
# 10317.000023006           16.380439          7.891289          31.887049
# 10317.000001887           14.550630         17.381040          42.402729
# 10317.000022505            6.271342          8.387836          38.442730
# 10317.000029153           18.337479          8.063864          27.004500
# 10317.000023881            8.671369         13.818850          35.210628
# 10317.000026141            4.699424         22.342377          30.455280
# 10317.000023342            8.845506          8.488574          29.305427
# 10317.000029559           10.676246          9.010740          27.577428
# 10317.000029169           12.265617         10.567095          31.193723
# 10317.000011337            7.179479          6.617179          41.190748
# 10317.000031473           18.921727          8.801973          25.877454
#
#                     lnAGE
# #SampleID
# 10317.000010218  3.988984
# 10317.000031464  4.143135
# 10317.000028712  3.988984
# 10317.000031298  4.007333
# 10317.000012905  3.433987
# 10317.000028809  4.077537
# 10317.000013266  4.276666
# 10317.000017274  4.127134
# 10317.000011281  3.850148
# 10317.000026662  3.891820
# 10317.000022898  4.127134
# 10317.000027852  4.174387
# 10317.000023015  4.343805
# 10317.000031468  3.688879
# 10317.000027213  3.737670
# 10317.000023006  3.761200
# 10317.000001887  4.127134
# 10317.000022505  4.043051
# 10317.000029153  3.784190
# 10317.000023881  4.174387
# 10317.000026141  4.110874
# 10317.000023342  3.970292
# 10317.000029559  4.158883
# 10317.000029169  3.988984
# 10317.000011337  4.189655
# 10317.000031473  4.158883
#
# [26 rows x 260 columns]

# %%
age_ = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=map_[watch_cols]).fit()
lage = smf.ols('PD_whole_tree_10k ~ lnAGE', data=map_[watch_cols]).fit()

# %%
print age_.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     62.42
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           3.71e-15
# Time:                        12:57:32   Log-Likelihood:                -11093.
# No. Observations:                3426   AIC:                         2.219e+04
# Df Residuals:                    3424   BIC:                         2.220e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        28.4180      0.382     74.326      0.000        27.668    29.168
# AGE_CORRECTED     0.0584      0.007      7.901      0.000         0.044     0.073
# ==============================================================================
# Omnibus:                        4.688   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                4.670
# Skew:                          -0.090   Prob(JB):                       0.0968
# Kurtosis:                       3.008   Cond. No.                         188.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print lage.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     71.43
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           4.20e-17
# Time:                        12:57:33   Log-Likelihood:                -11088.
# No. Observations:                3426   AIC:                         2.218e+04
# Df Residuals:                    3424   BIC:                         2.219e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     20.2344      1.316     15.375      0.000        17.654    22.815
# lnAGE          2.8715      0.340      8.452      0.000         2.205     3.538
# ==============================================================================
# Omnibus:                        4.917   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.086   Jarque-Bera (JB):                4.900
# Skew:                          -0.093   Prob(JB):                       0.0863
# Kurtosis:                       3.009   Cond. No.                         51.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
map_.groupby('SEX').count().max(1)
# Out:
# SEX
# (0) female    1794
# (1) male      1466
# dtype: int64

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     25.02
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           5.33e-16
# Time:                        12:57:45   Log-Likelihood:                -10555.
# No. Observations:                3260   AIC:                         2.112e+04
# Df Residuals:                    3256   BIC:                         2.114e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# Intercept                21.5156      1.848     11.643      0.000        17.892    25.139
# SEX[T.(1) male]          -3.5859      2.711     -1.323      0.186        -8.902     1.730
# lnAGE                     2.5633      0.477      5.374      0.000         1.628     3.499
# lnAGE:SEX[T.(1) male]     0.8672      0.700      1.238      0.216        -0.506     2.240
# ==============================================================================
# Omnibus:                        5.882   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                5.849
# Skew:                          -0.103   Prob(JB):                       0.0537
# Kurtosis:                       3.023   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     33.27
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           4.04e-39
# Time:                        12:57:51   Log-Likelihood:                -10312.
# No. Observations:                3208   AIC:                         2.064e+04
# Df Residuals:                    3201   BIC:                         2.068e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------
# Intercept                        21.9300      1.817     12.066      0.000        18.367    25.493
# SEX[T.(1) male]                  -3.0544      2.677     -1.141      0.254        -8.303     2.194
# COUNTRY[T.(1) Australia]          2.1680      0.701      3.091      0.002         0.793     3.543
# COUNTRY[T.(2) Canada]             1.2697      0.916      1.385      0.166        -0.527     3.067
# COUNTRY[T.(3) United Kingdom]     3.5798      0.323     11.076      0.000         2.946     4.214
# lnAGE                             2.3099      0.469      4.922      0.000         1.390     3.230
# lnAGE:SEX[T.(1) male]             0.7381      0.691      1.068      0.286        -0.617     2.093
# ==============================================================================
# Omnibus:                        7.940   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                7.891
# Skew:                          -0.115   Prob(JB):                       0.0193
# Kurtosis:                       3.079   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     35.03
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           2.89e-47
# Time:                        12:57:57   Log-Likelihood:                -9557.5
# No. Observations:                2989   AIC:                         1.913e+04
# Df Residuals:                    2981   BIC:                         1.918e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------------
# Intercept                        22.3495      1.859     12.023      0.000        18.705    25.994
# SEX[T.(1) male]                  -2.8639      2.735     -1.047      0.295        -8.227     2.499
# COUNTRY[T.(1) Australia]          2.5750      0.729      3.532      0.000         1.145     4.005
# COUNTRY[T.(2) Canada]             0.7214      0.923      0.782      0.434        -1.088     2.531
# COUNTRY[T.(3) United Kingdom]     3.6970      0.336     10.990      0.000         3.037     4.357
# IBD[T.(0) Yes]                   -4.4066      0.710     -6.208      0.000        -5.798    -3.015
# lnAGE                             2.2428      0.480      4.672      0.000         1.302     3.184
# lnAGE:SEX[T.(1) male]             0.6966      0.706      0.987      0.324        -0.688     2.081
# ==============================================================================
# Omnibus:                        6.780   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                6.717
# Skew:                          -0.110   Prob(JB):                       0.0348
# Kurtosis:                       3.074   Cond. No.                         131.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     30.26
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           5.96e-51
# Time:                        12:58:30   Log-Likelihood:                -9238.2
# No. Observations:                2896   AIC:                         1.850e+04
# Df Residuals:                    2886   BIC:                         1.856e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                23.8115      2.078     11.459      0.000        19.737    27.886
# SEX[T.(1) male]                          -1.9116      2.784     -0.687      0.492        -7.371     3.548
# COUNTRY[T.(1) Australia]                  2.2750      0.736      3.093      0.002         0.833     3.717
# COUNTRY[T.(2) Canada]                     0.5831      0.928      0.628      0.530        -1.236     2.403
# COUNTRY[T.(3) United Kingdom]             3.6329      0.342     10.631      0.000         2.963     4.303
# IBD[T.(0) Yes]                           -4.5808      0.715     -6.404      0.000        -5.983    -3.178
# RACE[T.(1) Caucasian]                     0.3440      0.861      0.400      0.689        -1.343     2.031
# RACE[T.(2) Asian or Pacific Islander]    -3.1951      1.015     -3.147      0.002        -5.186    -1.204
# lnAGE                                     1.8250      0.494      3.695      0.000         0.857     2.794
# lnAGE:SEX[T.(1) male]                     0.4579      0.718      0.638      0.523        -0.949     1.865
# ==============================================================================
# Omnibus:                        9.563   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.652
# Skew:                          -0.123   Prob(JB):                      0.00802
# Kurtosis:                       3.138   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     31.78
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           2.17e-69
# Time:                        12:59:09   Log-Likelihood:                -9122.7
# No. Observations:                2875   AIC:                         1.827e+04
# Df Residuals:                    2862   BIC:                         1.835e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     21.8175      2.119     10.296      0.000        17.663    25.972
# SEX[T.(1) male]                               -2.8281      2.752     -1.028      0.304        -8.225     2.569
# COUNTRY[T.(1) Australia]                       2.4594      0.729      3.372      0.001         1.029     3.889
# COUNTRY[T.(2) Canada]                          0.4743      0.913      0.519      0.603        -1.316     2.265
# COUNTRY[T.(3) United Kingdom]                  3.6745      0.338     10.865      0.000         3.011     4.338
# IBD[T.(0) Yes]                                -4.2590      0.708     -6.014      0.000        -5.648    -2.870
# RACE[T.(1) Caucasian]                          0.2725      0.865      0.315      0.753        -1.424     1.969
# RACE[T.(2) Asian or Pacific Islander]         -3.3037      1.015     -3.256      0.001        -5.293    -1.314
# ANTIBIOTIC_HISTORY[T.(1) 6 months]            -0.1615      0.577     -0.280      0.780        -1.293     0.970
# ANTIBIOTIC_HISTORY[T.(2) Year]                 0.7351      0.565      1.302      0.193        -0.372     1.842
# ANTIBIOTIC_HISTORY[T.(3) More than a year]     2.5864      0.501      5.163      0.000         1.604     3.569
# lnAGE                                          1.8713      0.489      3.829      0.000         0.913     2.830
# lnAGE:SEX[T.(1) male]                          0.6874      0.709      0.969      0.333        -0.704     2.078
# ==============================================================================
# Omnibus:                        5.019   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.081   Jarque-Bera (JB):                5.065
# Skew:                          -0.078   Prob(JB):                       0.0795
# Kurtosis:                       3.134   Cond. No.                         140.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.110
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     37.35
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           1.15e-69
# Time:                        12:59:47   Log-Likelihood:                -9596.9
# No. Observations:                3022   AIC:                         1.922e+04
# Df Residuals:                    3011   BIC:                         1.928e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     20.7577      1.634     12.707      0.000        17.555    23.961
# COUNTRY[T.(1) Australia]                       2.1933      0.720      3.048      0.002         0.782     3.604
# COUNTRY[T.(2) Canada]                          0.3979      0.914      0.435      0.664        -1.395     2.191
# COUNTRY[T.(3) United Kingdom]                  3.6022      0.336     10.711      0.000         2.943     4.262
# IBD[T.(0) Yes]                                -4.2473      0.685     -6.203      0.000        -5.590    -2.905
# RACE[T.(1) Caucasian]                          0.4044      0.857      0.472      0.637        -1.276     2.085
# RACE[T.(2) Asian or Pacific Islander]         -3.2754      1.007     -3.252      0.001        -5.250    -1.301
# ANTIBIOTIC_HISTORY[T.(1) 6 months]             0.1092      0.563      0.194      0.846        -0.996     1.214
# ANTIBIOTIC_HISTORY[T.(2) Year]                 0.7645      0.554      1.381      0.168        -0.321     1.850
# ANTIBIOTIC_HISTORY[T.(3) More than a year]     2.6292      0.491      5.355      0.000         1.667     3.592
# lnAGE                                          2.0923      0.351      5.953      0.000         1.403     2.781
# ==============================================================================
# Omnibus:                        3.723   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.155   Jarque-Bera (JB):                3.686
# Skew:                          -0.068   Prob(JB):                        0.158
# Kurtosis:                       3.104   Cond. No.                         72.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY + BOWEL_MOVEMENT_QUALITY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     12.09
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           4.79e-25
# Time:                        13:00:28   Log-Likelihood:                -3780.1
# No. Observations:                1184   AIC:                             7588.
# Df Residuals:                    1170   BIC:                             7659.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     22.3101      3.455      6.457      0.000        15.531    29.090
# SEX[T.(1) male]                               -0.5441      4.506     -0.121      0.904        -9.385     8.296
# COUNTRY[T.(1) Australia]                       2.5709      0.839      3.066      0.002         0.926     4.216
# COUNTRY[T.(2) Canada]                          0.4870      1.417      0.344      0.731        -2.292     3.266
# COUNTRY[T.(3) United Kingdom]                  3.1664      0.403      7.854      0.000         2.375     3.957
# IBD[T.(0) Yes]                              2.231e-14   8.25e-15      2.702      0.007      6.11e-15  3.85e-14
# RACE[T.(1) Caucasian]                          0.3139      1.349      0.233      0.816        -2.334     2.962
# RACE[T.(2) Asian or Pacific Islander]         -2.6908      1.609     -1.672      0.095        -5.849     0.467
# ANTIBIOTIC_HISTORY[T.(1) 6 months]             0.0091      1.001      0.009      0.993        -1.954     1.973
# ANTIBIOTIC_HISTORY[T.(2) Year]                 0.4381      0.961      0.456      0.649        -1.447     2.323
# ANTIBIOTIC_HISTORY[T.(3) More than a year]     2.3235      0.883      2.631      0.009         0.591     4.056
# BOWEL_MOVEMENT_QUALITY[T.(1) Constipated]     -0.2696      0.518     -0.521      0.603        -1.285     0.746
# BOWEL_MOVEMENT_QUALITY[T.(2) Diarrhea]        -2.4386      0.500     -4.878      0.000        -3.419    -1.458
# lnAGE                                          2.0741      0.791      2.621      0.009         0.521     3.627
# lnAGE:SEX[T.(1) male]                         -0.0299      1.155     -0.026      0.979        -2.295     2.235
# ==============================================================================
# Omnibus:                        4.984   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                5.484
# Skew:                          -0.081   Prob(JB):                       0.0644
# Kurtosis:                       3.291   Cond. No.                     2.05e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.15e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE + COUNTRY + IBD + RACE + ANTIBIOTIC_HISTORY + BOWEL_MOVEMENT_QUALITY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     13.95
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           1.71e-25
# Time:                        13:01:13   Log-Likelihood:                -3796.7
# No. Observations:                1189   AIC:                             7617.
# Df Residuals:                    1177   BIC:                             7678.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     21.8874      2.721      8.043      0.000        16.548    27.227
# COUNTRY[T.(1) Australia]                       2.4853      0.837      2.968      0.003         0.842     4.128
# COUNTRY[T.(2) Canada]                          0.4740      1.416      0.335      0.738        -2.304     3.252
# COUNTRY[T.(3) United Kingdom]                  3.1173      0.402      7.753      0.000         2.328     3.906
# IBD[T.(0) Yes]                             -6.992e-15   1.59e-15     -4.393      0.000     -1.01e-14 -3.87e-15
# RACE[T.(1) Caucasian]                          0.3466      1.346      0.257      0.797        -2.295     2.988
# RACE[T.(2) Asian or Pacific Islander]         -2.6528      1.608     -1.650      0.099        -5.807     0.501
# ANTIBIOTIC_HISTORY[T.(1) 6 months]             0.0025      1.000      0.003      0.998        -1.960     1.965
# ANTIBIOTIC_HISTORY[T.(2) Year]                 0.4444      0.960      0.463      0.644        -1.440     2.329
# ANTIBIOTIC_HISTORY[T.(3) More than a year]     2.3374      0.882      2.649      0.008         0.606     4.068
# BOWEL_MOVEMENT_QUALITY[T.(1) Constipated]     -0.1354      0.512     -0.264      0.792        -1.140     0.870
# BOWEL_MOVEMENT_QUALITY[T.(2) Diarrhea]        -2.3176      0.495     -4.685      0.000        -3.288    -1.347
# lnAGE                                          2.0941      0.587      3.569      0.000         0.943     3.245
# ==============================================================================
# Omnibus:                        5.367   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.068   Jarque-Bera (JB):                5.881
# Skew:                          -0.091   Prob(JB):                       0.0528
# Kurtosis:                       3.292   Cond. No.                     1.54e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.91e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
age2 = smf.ols('PD_whole_tree_10k ~ lnAGE*SEX + COUNTRY + IBD + ANTIBIOTIC_HISTORY + BOWEL_MOVEMENT_QUALITY', data=map_[watch_cols]).fit()
print age2.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      PD_whole_tree_10k   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.103
# Method:                 Least Squares   F-statistic:                     13.69
# Date:                Sun, 07 Feb 2016   Prob (F-statistic):           5.14e-25
# Time:                        13:01:29   Log-Likelihood:                -3899.6
# No. Observations:                1219   AIC:                             7823.
# Df Residuals:                    1207   BIC:                             7884.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------
# Intercept                                     21.0869      3.103      6.795      0.000        14.998    27.176
# SEX[T.(1) male]                               -2.1136      4.397     -0.481      0.631       -10.741     6.514
# COUNTRY[T.(1) Australia]                       2.8788      0.826      3.486      0.001         1.258     4.499
# COUNTRY[T.(2) Canada]                          0.6833      1.423      0.480      0.631        -2.108     3.474
# COUNTRY[T.(3) United Kingdom]                  3.2764      0.397      8.262      0.000         2.498     4.055
# IBD[T.(0) Yes]                             -1.673e-14   9.25e-15     -1.809      0.071     -3.49e-14  1.41e-15
# ANTIBIOTIC_HISTORY[T.(1) 6 months]             0.2764      0.992      0.279      0.780        -1.669     2.222
# ANTIBIOTIC_HISTORY[T.(2) Year]                 0.5988      0.956      0.627      0.531        -1.276     2.474
# ANTIBIOTIC_HISTORY[T.(3) More than a year]     2.3924      0.878      2.723      0.007         0.669     4.116
# BOWEL_MOVEMENT_QUALITY[T.(1) Constipated]     -0.3771      0.511     -0.739      0.460        -1.379     0.625
# BOWEL_MOVEMENT_QUALITY[T.(2) Diarrhea]        -2.4266      0.495     -4.902      0.000        -3.398    -1.455
# lnAGE                                          2.4032      0.761      3.157      0.002         0.910     3.897
# lnAGE:SEX[T.(1) male]                          0.3583      1.128      0.318      0.751        -1.855     2.572
# ==============================================================================
# Omnibus:                        2.993   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.224   Jarque-Bera (JB):                2.938
# Skew:                          -0.083   Prob(JB):                        0.230
# Kurtosis:                       3.174   Cond. No.                     2.08e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.85e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
map_[watch_cols].groupby(('IBD', 'BOWEL_MOVEMENT_QUALITY')).count().max(1)
# Out:
# IBD     BOWEL_MOVEMENT_QUALITY
# (0) No  (0) Normal                905
#         (1) Constipated           176
#         (2) Diarrhea              184
# dtype: int64

# %%
questions
# Out:
# ['IBD',
#  'SEX',
#  'ANTIBIOTIC_HISTORY',
#  'COUNTRY',
#  'RACE',
#  'BOWEL_MOVEMENT_QUALITY',
#  'BOWEL_MOVEMENT_FREQUENCY',
#  'AGE_CORRECTED',
#  'VIOSCREEN_MANNITOL',
#  'VIOSCREEN_SFA100',
#  'VIOSCREEN_SFA170',
#  'VIOSCREEN_VEGETABLE_SERVINGS',
#  'VIOSCREEN_SORBITOL',
#  'VIOSCREEN_SFA80',
#  'VIOSCREEN_BETACAR',
#  'VIOSCREEN_LOW_FAT_DAIRY_SERVING',
#  'VIOSCREEN_NIACINEQ',
#  'VIOSCREEN_GAMMTOCO',
#  'VIOSCREEN_LYSINE',
#  'VIOSCREEN_ISOMALT',
#  'VIOSCREEN_SUCROSE',
#  'VIOSCREEN_CLAC9T11',
#  'VIOSCREEN_FIBER',
#  'VIOSCREEN_LACTITOL',
#  'VIOSCREEN_HEI_NON_JUICE_FRT',
#  'VIOSCREEN_OXALICM',
#  'VIOSCREEN_ALPHACAR',
#  'VIOSCREEN_LYCOPENE',
#  'VIOSCREEN_VEG5_DAY',
#  'VIOSCREEN_HEI_MILK',
#  'VIOSCREEN_CLAT10C12',
#  'VIOSCREEN_HEI_MEAT_BEANS',
#  'VIOSCREEN_HEI_SOL_FAT_ALC_ADD_SUG',
#  'VIOSCREEN_COPPER',
#  'VIOSCREEN_HEI2010_REFINED_GRAINS',
#  'VIOSCREEN_LUTZEAX',
#  'VIOSCREEN_SALAD_VEGETABLE_SERVINGS',
#  'VIOSCREEN_SFA200',
#  'VIOSCREEN_HEI2010_DAIRY',
#  'VIOSCREEN_FIBH2O',
#  'VIOSCREEN_GLAC',
#  'VIOSCREEN_SFA140',
#  'VIOSCREEN_TAGATOSE',
#  'VIOSCREEN_D_YOGURT',
#  'VIOSCREEN_VISIT',
#  'VIOSCREEN_HEI2010_WHOLE_GRAINS',
#  'VIOSCREEN_MULTI_CALCIUM_AVG',
#  'VIOSCREEN_F_NJ_OTHER',
#  'VIOSCREEN_D_MILK',
#  'VIOSCREEN_M_ORGAN',
#  'VIOSCREEN_M_POULT',
#  'VIOSCREEN_M_MPF',
#  'VIOSCREEN_WHOLE_GRAIN_SERVINGS',
#  'VIOSCREEN_HEI2010_PROTIEN_FOODS',
#  'VIOSCREEN_NCCGLGR',
#  'VIOSCREEN_OXALIC',
#  'VIOSCREEN_HEI_FRUIT',
#  'VIOSCREEN_MFA161',
#  'VIOSCREEN_SATOCO',
#  'VIOSCREEN_RIBOFLA',
#  'VIOSCREEN_STARCH',
#  'VIOSCREEN_MFA221',
#  'VIOSCREEN_V_TOTAL',
#  'VIOSCREEN_V_ORANGE',
#  'VIOSCREEN_M_FRANK',
#  'VIOSCREEN_DELTTOCO',
#  'VIOSCREEN_FRUIT_SERVINGS',
#  'VIOSCREEN_BETATOCO',
#  'VIOSCREEN_FRIED_FOOD_SERVINGS',
#  'VIOSCREEN_FISH_SERVINGS',
#  'VIOSCREEN_FRTSUMM',
#  'VIOSCREEN_GRAMS',
#  'VIOSCREEN_VALINE',
#  'VIOSCREEN_HEI_SODIUM',
#  'VIOSCREEN_HISTIDIN',
#  'VIOSCREEN_BETAINE',
#  'VIOSCREEN_ALCOHOL_SERVINGS',
#  'VIOSCREEN_SFATOT',
#  'VIOSCREEN_POTASS',
#  'VIOSCREEN_PHYTIC',
#  'VIOSCREEN_PECTINS',
#  'VIOSCREEN_SFA180',
#  'VIOSCREEN_FOL_SYN',
#  'VIOSCREEN_F_NJ_TOTAL',
#  'VIOSCREEN_A_CAL',
#  'VIOSCREEN_V_TOMATO',
#  'VIOSCREEN_LEUCINE',
#  'VIOSCREEN_CALORIES',
#  'VIOSCREEN_A_BEV',
#  'VIOSCREEN_HEI2010_EMPTY_CALORIES',
#  'VIOSCREEN_LEGUMES',
#  'VIOSCREEN_BETACRYP',
#  'VIOSCREEN_HEI2010_SODIUM',
#  'VIOSCREEN_TRYPTOPH',
#  'VIOSCREEN_TOTALTFA',
#  'VIOSCREEN_ALCOHOL',
#  'VIOSCREEN_SACCHAR',
#  'VIOSCREEN_ERYTHR',
#  'VIOSCREEN_D_TOTAL',
#  'VIOSCREEN_F_TOTAL',
#  'VIOSCREEN_NON_FRIED_FISH_SERVINGS',
#  'VIOSCREEN_ADD_SUG',
#  'VIOSCREEN_PFA225',
#  'VIOSCREEN_PFA226',
#  'VIOSCREEN_HEI_SCORE',
#  'VIOSCREEN_FAT',
#  'VIOSCREEN_PROLINE',
#  'VIOSCREEN_M_MEAT',
#  'VIOSCREEN_CALCIUM_AVG',
#  'VIOSCREEN_G_WHL',
#  'VIOSCREEN_PROTANIM',
#  'VIOSCREEN_MALTITOL',
#  'VIOSCREEN_CALCIUM_SERVINGS',
#  'VIOSCREEN_FOL_NAT',
#  'VIOSCREEN_MAGNES',
#  'VIOSCREEN_VITA_RE',
#  'VIOSCREEN_VEGSUMM',
#  'VIOSCREEN_SFA60',
#  'VIOSCREEN_HEI2010_WHOLE_FRUIT',
#  'VIOSCREEN_HEI_SAT_FAT',
#  'VIOSCREEN_TOTFOLAT',
#  'VIOSCREEN_ARGININE',
#  'VIOSCREEN_HEI2010_FATTY_ACIDS',
#  'VIOSCREEN_PHENYLAL',
#  'VIOSCREEN_ALPHTOCE',
#  'VIOSCREEN_PROTEIN',
#  'VIOSCREEN_ALPHTOCO',
#  'VIOSCREEN_GLTC',
#  'VIOSCREEN_MULTI_CALCIUM_DOSE',
#  'VIOSCREEN_VITA_IU',
#  'VIOSCREEN_NIACIN',
#  'VIOSCREEN_SELENIUM',
#  'VIOSCREEN_TOTCLA',
#  'VIOSCREEN_PFA184',
#  'VIOSCREEN_PFA183',
#  'VIOSCREEN_PFA182',
#  'VIOSCREEN_D_TOT_SOYM',
#  'VIOSCREEN_DISCFAT_OIL',
#  'VIOSCREEN_GALACTOS',
#  'VIOSCREEN_JUICE_SERVINGS',
#  'VIOSCREEN_FRT5_DAY',
#  'VIOSCREEN_PINITOL',
#  'VIOSCREEN_GENISTN',
#  'VIOSCREEN_SFA120',
#  'VIOSCREEN_HEI_GRAINS',
#  'VIOSCREEN_METHION',
#  'VIOSCREEN_HEI_VEG',
#  'VIOSCREEN_GLUCOSE',
#  'VIOSCREEN_CHOLINE',
#  'VIOSCREEN_ISOLEUC',
#  'VIOSCREEN_FOL_DEQV',
#  'VIOSCREEN_COUMEST',
#  'VIOSCREEN_TFA161T',
#  'VIOSCREEN_XYLITOL',
#  'VIOSCREEN_BIOCHANA',
#  'VIOSCREEN_F_NJ_CITMLB',
#  'VIOSCREEN_HEI2010_VEG',
#  'VIOSCREEN_M_NUTSD',
#  'VIOSCREEN_PFATOT',
#  'VIOSCREEN_FIBINSO',
#  'VIOSCREEN_V_OTHER',
#  'VIOSCREEN_WGRAIN',
#  'VIOSCREEN_TFA182T',
#  'VIOSCREEN_G_TOTAL',
#  'VIOSCREEN_M_FISH_LO',
#  'VIOSCREEN_VITD2',
#  'VIOSCREEN_RETINOL',
#  'VIOSCREEN_MFATOT',
#  'VIOSCREEN_CYSTINE',
#  'VIOSCREEN_V_POTATO',
#  'VIOSCREEN_PANTOTHE',
#  'VIOSCREEN_RECNO',
#  'VIOSCREEN_ASH',
#  'VIOSCREEN_PHOSPHOR',
#  'VIOSCREEN_CALCIUM_FROM_DAIRY_SERVINGS',
#  'VIOSCREEN_ASPARTIC',
#  'VIOSCREEN_V_STARCY',
#  'VIOSCREEN_SFA220',
#  'VIOSCREEN_F_CITMLB',
#  'VIOSCREEN_HEI_WHL_GRAINS',
#  'VIOSCREEN_THREONIN',
#  'VIOSCREEN_M_EGG',
#  'VIOSCREEN_HEI2010_FRUIT',
#  'VIOSCREEN_DISCFAT_SOL',
#  'VIOSCREEN_TYROSINE',
#  'VIOSCREEN_WATER',
#  'VIOSCREEN_MFA141',
#  'VIOSCREEN_HEI2010_SCORE',
#  'VIOSCREEN_VITD',
#  'VIOSCREEN_VITC',
#  'VIOSCREEN_VITK',
#  'VIOSCREEN_SFA160',
#  'VIOSCREEN_FRUCTOSE',
#  'VIOSCREEN_ADDSUGAR',
#  'VIOSCREEN_MFA201',
#  'VIOSCREEN_RGRAIN',
#  'VIOSCREEN_V_DRKGR',
#  'VIOSCREEN_CALCIUM_DOSE',
#  'VIOSCREEN_F_OTHER',
#  'VIOSCREEN_ADSUGTOT',
#  'VIOSCREEN_IRON',
#  'VIOSCREEN_ZINC',
#  'VIOSCREEN_AVCARB',
#  'VIOSCREEN_OMEGA3',
#  'VIOSCREEN_TOTSUGAR',
#  'VIOSCREEN_SRVID',
#  'VIOSCREEN_LINE_GI',
#  'VIOSCREEN_TGRAIN',
#  'VIOSCREEN_SUCRLOSE',
#  'VIOSCREEN_M_SOY',
#  'VIOSCREEN_SUCPOLY',
#  'VIOSCREEN_ALANINE',
#  'VIOSCREEN_CARBO',
#  'VIOSCREEN_MFA181',
#  'VIOSCREEN_M_FISH_HI',
#  'VIOSCREEN_TFA181T',
#  'VIOSCREEN_VITD3',
#  'VIOSCREEN_ACESUPOT',
#  'VIOSCREEN_GLUTAMIC',
#  'VIOSCREEN_HEI2010_SEA_FOODS_PLANT_PROTIENS',
#  'VIOSCREEN_SODIUM',
#  'VIOSCREEN_THIAMIN',
#  'VIOSCREEN_ASPARTAM',
#  'VIOSCREEN_VITD_IU',
#  'VIOSCREEN_USER_ID',
#  'VIOSCREEN_HEI_DRK_G_ORG_VEG_LEG',
#  'VIOSCREEN_INOSITOL',
#  'VIOSCREEN_FRIED_FISH_SERVINGS',
#  'VIOSCREEN_VITB12',
#  'VIOSCREEN_SFA40',
#  'VIOSCREEN_TIME',
#  'VIOSCREEN_VITE_IU',
#  'VIOSCREEN_VITA_RAE',
#  'VIOSCREEN_MANGAN',
#  'VIOSCREEN_PROTVEG',
#  'VIOSCREEN_AGE',
#  'VIOSCREEN_GLYCITN',
#  'VIOSCREEN_GLYCINE',
#  'VIOSCREEN_LACTOSE',
#  'VIOSCREEN_VITB6',
#  'VIOSCREEN_D_CHEESE',
#  'VIOSCREEN_NCCGLBR',
#  'VIOSCREEN_HEI2010_GREENS_BEANS',
#  'VIOSCREEN_CAFFEINE',
#  'VIOSCREEN_DAIDZEIN',
#  'VIOSCREEN_NITROGEN',
#  'VIOSCREEN_SERINE',
#  'VIOSCREEN_PFA204',
#  'VIOSCREEN_PFA205',
#  'VIOSCREEN_G_NWHL',
#  'VIOSCREEN_MALTOSE',
#  'VIOSCREEN_HEI_OILS',
#  'VIOSCREEN_JOULES',
#  'VIOSCREEN_FORMONTN',
#  'VIOSCREEN_SWEET_SERVINGS',
#  'VIOSCREEN_CHOLEST',
#  'VIOSCREEN_METHHIS3',
#  'VIOSCREEN_NATOCO',
#  'PD_whole_tree_10k',
#  'lnAGE']

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=map_.loc[map_.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map = map_.loc[map_[['AGE_CORRECTED', 'VIOSCREEN_FIBER']].dropna().index]
sub_map['COUNTRY'] = sub_map.COUNTRY.apply(lambda x: x if x in {'USA', 'United Kingdom'} else np.nan)

# %%
f_ = lambda x: x if x in {'USA', 'United Kingdom'} else np.nan

# %%
abx = agdic.ag_dictionary('ANTIBIOTIC_HISTORY')
abx.remap_groups(sub_map)
abx.label_order(sub_map)

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map['lnAge'] = sub_map.AGE_CORRECTED.apply(lambda x: np.log(x))
sub_map.loc[sub_map.AGE_CORRECTED < 20, 'lnAge'] = np.nan

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge + COUNTRY', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ lnAge + COUNTRY + ANTIBIOTIC_HISTORY', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
mod = smf.ols('PD_whole_tree_10k ~ AGE_CORRECTED + COUNTRY + VIOSCREEN_HEI_SCORE', data=sub_map.loc[sub_map.AGE_CORRECTED > 20]).fit()
print mod.summary()

# %%
sub_map.loc[sub_map.AGE_CORRECTED > 20].shape

# %%
plt.plot(map_['VIOSCREEN_FIBER'], map_['PD_whole_tree_10k'], 'o')

# %%
sorted(vios_cols)

# %%
vios_cols
